# %%
import logging

# %%
# Create a logger for module1
logger1 = logging.getLogger('module1')
logger1.setLevel(logging.DEBUG)

# Logger for module2
logger2 = logging.getLogger('module2')
logger2.setLevel(logging.WARNING)

# %%
# Configuring logging settings
logging.basicConfig(
  level=logging.DEBUG,
  format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
  datefmt='%Y-%M-%d %H:%M:%S'
)

# %%
# Log messages with different loggers
logger1.debug('Debug message for module1')
logger2.warning('Warning message for Module2')
logger2.error('Error message for Module2')
# Out:
# 2025-49-08 12:49:57-module1-DEBUG-Debug message for module1
# 2025-49-08 12:49:57-module2-WARNING-Warning message for Module2
# 2025-49-08 12:49:57-module2-ERROR-Error message for Module2
