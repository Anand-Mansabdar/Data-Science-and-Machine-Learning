# %% [markdown]
# #### HANDLING OUTLIERS
#
# 5 Number Summary and Box Plot
#
# 1 - Minimum
# 2 - Maximum
# 3 - Median
# 4 - Q1
# 5 - Q3
# 6 - IQR

# %%
import numpy as np
import seaborn as sns

# %%
marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74]

# %%
minimum, Q1, median, Q3, maximum = np.quantile(marks, [0, 0.25, 0.50, 0.75, 1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence = Q1 - 1.5 * (IQR)
higher_fence = Q3 + 1.5 * (IQR)

print(lower_fence, higher_fence)
# Out:
# 1.5 141.5

# %%
sns.boxplot(marks)
# Out:
# <Axes: >

# %%
# Adding more values to get outliers
marks = [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74, 150, 170, 200]

# %%
sns.boxplot(marks)
# Out:
# <Axes: >
