# %%
import math

print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
print(np.round(3.12))
print(np.array([1, 2, 3, 4, 5]))
# Out:
# 3.0
# [1 2 3 4 5]

# %%
from math import *
print(sqrt(387))
print(round(pi, 3))
# Out:
# 19.672315572906
# 3.142

# %%
from package import greet
print(greet.greet('Anand'))
print(greet.intro('Virat Kohli'))
# Out:
# Hello Anand
# My name is Virat Kohli
