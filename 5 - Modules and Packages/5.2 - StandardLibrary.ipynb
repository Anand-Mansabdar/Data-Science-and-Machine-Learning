# %%
import array
arr = array.array('i', [1, 2, 3, 4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
# random library

import random
print(random.randint(1, 100))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 8
# banana

# %%
# File and directory access :- os

import os
print(os.getcwd()) # Gets the current working directory
os.mkdir('test_dir') # Creates a directory in the current working directory
# Out:
# c:\Users\anand\Desktop\Data Science\5 - Modules and Packages

# %%
# high level operations on files and collection of files
import shutil
shutil.copyfile('source.txt', 'destination.txt') # Copies the content of source.txt to destination.txt
# Out:
# 'destination.txt'

# %%
# Data serialization
import json
data = {'name': 'Anand', 'age': 20}
print(json.dumps(data)) # Converts .json() data to a string
print(type(json.dumps(data)))

json_str = json.dumps(data)
parsed_json = json.loads(json_str)
print(parsed_json)
print(type(parsed_json))
# Out:
# {"name": "Anand", "age": 20}
# <class 'str'>
# {'name': 'Anand', 'age': 20}
# <class 'dict'>

# %%
# csv
import csv

# Writing into a CSV file
with open('example.csv', mode='w', newline='') as file:
  writer = csv.writer(file)
  writer.writerow(['name', 'age'])
  writer.writerow(['Anand Mansabdar', 20])
  
# Reading data from a CSV file
with open('example.csv' ,mode='r') as file:
  reader = csv.reader(file)
  for row in reader:
    print(row)
# Out:
# ['name', 'age']
# ['Anand Mansabdar', '20']

# %%
# datetime
from datetime import datetime, timedelta

print(datetime.now()) # current time and date
print(datetime.now()-timedelta(days=1)) # To fetch past date and time
# Out:
# 2025-11-03 17:23:22.131966
# 2025-11-02 17:23:22.131966

# %%
# time
import time
print(time.time()) # prints the current time
time.sleep(5) # pauses the calculation for specified amount of time. Here, 5 seconds
print(time.time())
# Out:
# 1762170914.1630087
# 1762170919.1639383

# %%
# Regular Expressions
import re

pattern = r'\d+'
text = 'There are 11 cricketers who play a match'
match = re.search(pattern, text)
print(match.group())
# Out:
# 11
