# %%
class Car:
  def __init__(self, windows, doors, engineType):
    self.windows = windows
    self.doors = doors
    self.engineType = engineType
  
  def drive(self):
    print(f'The person will drive the {self.engineType} car')
    
car1 = Car(4, 4, 'Petrol')
print(car1.windows)
car1.drive()
# Out:
# 4
# The person will drive the Petrol car

# %%
class Audi(Car):
   def __init__(self, windows, doors, engineType, is_hybrid):
      super().__init__(windows, doors, engineType)
      self.is_hybrid = is_hybrid
      
   def isHybrid(self):
      if self.is_hybrid == True:
         print(f'This car is a hybrid car')
      else:
         print(f'This car is not a hybrid car')

audi1 = Audi(5, 4, 'petrol', False)
audi2 = Audi(4, 4, 'Petrol + Electric', True)
audi1.isHybrid()
print(audi2.engineType)
audi2.isHybrid()
# Out:
# This car is not a hybrid car
# Petrol + Electric
# This car is a hybrid car

# %%
# Multiple Inheritance :- when a class inherits from more than one base class
class Animal:
  def __init__(self, name):
    self.name = name
  
  def speak(self):
    print('SUbclass must implement this method')
    
class Pet:
  def __init__(self, owner):
    self.owner = owner
    
class Dog(Animal, Pet):
  def __init__(self, name, owner):
    Animal.__init__(self, name)
    Pet.__init__(self, owner)
    
  def speak(self):
    return f'{self.name} barks'
  
# Creating an instance
dog1 = Dog('Jazz','Anand')
print(dog1.name)
print(dog1.owner)
print(dog1.speak())
# Out:
# Jazz
# Anand
# Jazz barks
