# %%
class Error(Exception):
  pass

class dobException(Error):
  pass

year = int(input('Enter the DOB: '))
age = 2025 - year

try:
  if age <= 30 and age >= 20:
    print('The age is valid')
  else:
    raise dobException
except dobException:
  print('Your age does not follow the guidelines')
# Out:
# Your age does not follow the guidelines
