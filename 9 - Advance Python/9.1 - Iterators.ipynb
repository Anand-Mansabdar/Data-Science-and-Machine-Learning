# %%
my_list = [1, 2, 3, 4, 5, 6]
for i in my_list:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# Iteratoes
iterator = iter(my_list)

# %%
print(iterator)
print(type(iterator))
# Out:
# <list_iterator object at 0x000002BB5AEE0190>
# <class 'list_iterator'>

# %%
# Iterate through all the elements
iterator = iter(my_list)

# %%
try:
  print(next(iterator))
except:
  print('There are no elements in the iterator')
# Out:
# There are no elemets in the iterator
